# %%
from datetime import timedelta
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import plotly.express as px
from sodapy import Socrata
from keplergl import KeplerGl
import altair
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.cluster import KMeans
from sklearn import datasets
import ipywidgets
import requests
import seaborn as sns
import glob
import json
import os

# %%
d1 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202201-citibike-tripdata.csv')
d2 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202202-citibike-tripdata.csv')
d3 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202203-citibike-tripdata.csv')
d4 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202204-citibike-tripdata.csv')
d5 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202205-citibike-tripdata.csv')
d6 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202206-citibike-tripdata.csv')
d7 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202207-citbike-tripdata.csv')
d8 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202208-citibike-tripdata.csv')
d9 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202209-citibike-tripdata.csv')
d10 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202210-citibike-tripdata.csv')
d11 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202211-citibike-tripdata.csv')
d12 = pd.read_csv('C:\\Users\\ASUS\\NY Bikeshare\\Raw data csv\\JC-202212-citibike-tripdata.csv')

# %%
dataset = pd.concat([d1, d2,d3, d4, d5, d6, d7, d8, d9, d10, d11, d12])

# %%
dataset
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1      BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2      7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3      6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4      E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-01-26 18:51:53                    12 St & Sinatra Dr N
# 1      2022-01-28 13:20:23                        Essex Light Rail
# ...

# %%
dataset.to_csv('merged_dataset.csv', index=False)
